# %%
# !pip install  yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.7/site-packages (from yfinance) (1.1.4)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from yfinance) (1.18.5)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.7/site-packages (from yfinance) (2.23.0)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.1-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 7.3 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->yfinance) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2020.11.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.14.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22616 sha256=f8f30d54571fdc8c76b05b4c56574590af857803b37ca15e77b27c7fcf6307c4
#   Stored in directory: /root/.cache/pip/wheels/aa/8a/36/59ed4f6fbcb6100967618eeb0696046bf9777a41ac2ff1f9b9
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8366 sha256=d99029c407012b7f1480e378f484ac665af65f02f47df22dc16b15cbbc0bc988
#   Stored in directory: /root/.cache/pip/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, lxml, yfinance
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.5.0
#     Uninstalling lxml-4.5.0:
#       Successfully uninstalled lxml-4.5.0
# Successfully installed lxml-4.6.1 multitasking-0.0.9 yfinance-0.1.55

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import yfinance

# %%
HRB = "HRB"

# %%
HRB = yfinance.download("HRB")

HRB
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 1973-02-21   0.000000   0.476562   0.457031   0.460938   0.078111   339200
# 1973-02-22   0.000000   0.457031   0.437500   0.453125   0.076787   627200
# 1973-02-23   0.000000   0.449219   0.421875   0.421875   0.071492   668800
# 1973-02-26   0.000000   0.417969   0.410156   0.410156   0.069506   521600
# 1973-02-27   0.000000   0.417969   0.394531   0.394531   0.066858   816000
# ...               ...        ...        ...        ...        ...      ...
# 2020-11-19  18.340000  18.440001  17.879999  18.070000  18.070000  1585400
# 2020-11-20  17.889999  18.000000  17.740000  17.930000  17.930000  1522300
# 2020-11-23  18.190001  18.480000  17.990000  18.330000  18.330000  1795800
# 2020-11-24  18.530001  19.290001  18.410000  19.180000  19.180000  2573400
# 2020-11-25  19.200001  19.200001  18.600000  18.670000  18.670000  1961500
#
# [12050 rows x 6 columns]

# %%
HRB.head()
# Out:
#             Open      High       Low     Close  Adj Close  Volume
# Date
# 1973-02-21   0.0  0.476562  0.457031  0.460938   0.078111  339200
# 1973-02-22   0.0  0.457031  0.437500  0.453125   0.076787  627200
# 1973-02-23   0.0  0.449219  0.421875  0.421875   0.071492  668800
# 1973-02-26   0.0  0.417969  0.410156  0.410156   0.069506  521600
# 1973-02-27   0.0  0.417969  0.394531  0.394531   0.066858  816000

# %%
HRB.Close
# Out:
# Date
# 1973-02-21     0.460938
# 1973-02-22     0.453125
# 1973-02-23     0.421875
# 1973-02-26     0.410156
# 1973-02-27     0.394531
#                 ...
# 2020-11-19    18.070000
# 2020-11-20    17.930000
# 2020-11-23    18.330000
# 2020-11-24    19.180000
# 2020-11-25    18.670000
# Name: Close, Length: 12050, dtype: float64

# %%
plt.xlabel("days")         
plt.ylabel("price")    
plt.grid()              
plt.plot(HRB.Close)

# %%
HRB.High
# Out:
# Date
# 1973-02-21     0.476562
# 1973-02-22     0.457031
# 1973-02-23     0.449219
# 1973-02-26     0.417969
# 1973-02-27     0.417969
#                 ...
# 2020-11-19    18.440001
# 2020-11-20    18.000000
# 2020-11-23    18.480000
# 2020-11-24    19.290001
# 2020-11-25    19.200001
# Name: High, Length: 12050, dtype: float64

# %%
plt.xlabel("days")        
plt.ylabel("price")   
plt.grid()              
plt.plot(HRB.Close)

# %%
plt.plot(HRB.High)
plt.grid()

# %%
HRB.Open
# Out:
# Date
# 1973-02-21     0.000000
# 1973-02-22     0.000000
# 1973-02-23     0.000000
# 1973-02-26     0.000000
# 1973-02-27     0.000000
#                 ...
# 2020-11-19    18.340000
# 2020-11-20    17.889999
# 2020-11-23    18.190001
# 2020-11-24    18.530001
# 2020-11-25    19.200001
# Name: Open, Length: 12050, dtype: float64

# %%
print(len(HRB.Close))
las100_days = HRB.High[2316:2415]
plt.plot(las100_days)
# Out:
# 12050
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-22a7d5e736a0> in <module>
#       1 print(len(HRB.Close))
# ----> 2 las100_days = df.High[2316:2415]
#       3 plt.plot(las100_days)
#
# NameError: name 'df' is not defined
