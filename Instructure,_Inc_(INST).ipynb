# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock-/blob/master/Instructure%2C_Inc_(INST).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=0d5ff916944115e567a7ed45ac7f79d42830e62af8fde19f8667b64b1440a881
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import yfinance

# %%
INST = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/INST?period1=1565652691&period2=1597275091&interval=1d&events=history")

INST
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 0    2019-08-12  40.770000  40.950001  ...  39.730000  39.730000  652415.0
# 1    2019-08-13  39.500000  40.465000  ...  40.180000  40.180000  420547.0
# 2    2019-08-14  39.500000  40.570000  ...  40.110001  40.110001  345393.0
# 3    2019-08-15  40.200001  41.200001  ...  41.080002  41.080002  375171.0
# 4    2019-08-16  41.250000  42.099998  ...  41.830002  41.830002  289584.0
# ..          ...        ...        ...  ...        ...        ...       ...
# 248  2020-08-05        NaN        NaN  ...        NaN        NaN       NaN
# 249  2020-08-06        NaN        NaN  ...        NaN        NaN       NaN
# 250  2020-08-07        NaN        NaN  ...        NaN        NaN       NaN
# 251  2020-08-10        NaN        NaN  ...        NaN        NaN       NaN
# 252  2020-08-11        NaN        NaN  ...        NaN        NaN       NaN
#
# [253 rows x 7 columns]

# %%
INST.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2019-08-12  40.770000  40.950001  39.380001  39.730000  39.730000  652415.0
# 1  2019-08-13  39.500000  40.465000  39.500000  40.180000  40.180000  420547.0
# 2  2019-08-14  39.500000  40.570000  39.450001  40.110001  40.110001  345393.0
# 3  2019-08-15  40.200001  41.200001  39.935001  41.080002  41.080002  375171.0
# 4  2019-08-16  41.250000  42.099998  41.250000  41.830002  41.830002  289584.0

# %%
INST.tail()
# Out:
#            Date  Open  High  Low  Close  Adj Close  Volume
# 248  2020-08-05   NaN   NaN  NaN    NaN        NaN     NaN
# 249  2020-08-06   NaN   NaN  NaN    NaN        NaN     NaN
# 250  2020-08-07   NaN   NaN  NaN    NaN        NaN     NaN
# 251  2020-08-10   NaN   NaN  NaN    NaN        NaN     NaN
# 252  2020-08-11   NaN   NaN  NaN    NaN        NaN     NaN

# %%
INST.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  155.000000  155.000000  155.000000  155.000000  155.000000  1.550000e+02
# mean    45.783355   46.270026   45.358410   45.839742   45.839742  9.484766e+05
# std      4.319362    4.218446    4.420264    4.313717    4.313717  1.358620e+06
# min     37.270000   38.474998   37.060001   37.230000   37.230000  8.839000e+04
# 25%     41.515000   42.274999   41.010001   41.820002   41.820002  3.504280e+05
# 50%     47.799999   48.000000   47.610001   47.709999   47.709999  5.217410e+05
# 75%     48.614999   48.815000   48.340000   48.745001   48.745001  1.114612e+06
# max     54.000000   54.310001   52.970001   53.689999   53.689999  1.168770e+07

# %%
import sqlite3

# %%
conn = sqlite3.connect("INST.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("INST.db")
c = conn.cursor()

# %%
INST.to_sql("INST", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM INST""")
rows = c.fetchall()
rows
# Out:
# [(0, '2019-08-12', 40.77, 40.950001, 39.380001, 39.73, 39.73, 652415.0),
#  (1, '2019-08-13', 39.5, 40.465, 39.5, 40.18, 40.18, 420547.0),
#  (2,
#   '2019-08-14',
#   39.5,
#   40.57,
#   39.450001,
#   40.110001000000004,
#   40.110001000000004,
#   345393.0),
#  (3,
#   '2019-08-15',
#   40.200001,
#   41.200001,
#   39.935001,
#   41.080002,
#   41.080002,
#   375171.0),
#  (4, '2019-08-16', 41.25, 42.099998, 41.25, 41.830002, 41.830002, 289584.0),
#  (5,
#   '2019-08-19',
#   42.349998,
#   43.299999,
#   42.189999,
#   42.709998999999996,
#   42.709998999999996,
#   417818.0),
#  (6,
#   '2019-08-20',
#   42.580002,
#   43.540001000000004,
#   42.209998999999996,
#   43.310001,
#   43.310001,
#   403513.0),
#  (7, '2019-08-21', 43.48, 44.07, 42.450001, 42.869999, 42.869999, 343567.0),
#  (8,
#   '2019-08-22',
#   42.990002000000004,
#   43.259997999999996,
#   42.220001,
#   42.799999,
#   42.799999,
#   351747.0),
#  (9,
#   '2019-08-23',
#   42.709998999999996,
# ...

# %%
INST.to_excel("INST.xls")

pd.read_excel("INST.xls")
# Out:
#      Unnamed: 0        Date       Open  ...      Close  Adj Close    Volume
# 0             0  2019-08-12  40.770000  ...  39.730000  39.730000  652415.0
# 1             1  2019-08-13  39.500000  ...  40.180000  40.180000  420547.0
# 2             2  2019-08-14  39.500000  ...  40.110001  40.110001  345393.0
# 3             3  2019-08-15  40.200001  ...  41.080002  41.080002  375171.0
# 4             4  2019-08-16  41.250000  ...  41.830002  41.830002  289584.0
# ..          ...         ...        ...  ...        ...        ...       ...
# 248         248  2020-08-05        NaN  ...        NaN        NaN       NaN
# 249         249  2020-08-06        NaN  ...        NaN        NaN       NaN
# 250         250  2020-08-07        NaN  ...        NaN        NaN       NaN
# 251         251  2020-08-10        NaN  ...        NaN        NaN       NaN
# 252         252  2020-08-11        NaN  ...        NaN        NaN       NaN
#
# [253 rows x 8 columns]
